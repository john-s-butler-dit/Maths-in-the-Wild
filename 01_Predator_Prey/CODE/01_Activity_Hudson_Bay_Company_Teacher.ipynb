# %% [markdown]
# # Activity 1: Hudson Bay Company Data
#
# -------
#
# ### Overview
#
# In this tutorial you will learn:
# 1. How to load data from a file.
# 2. Explore the data to see what information it contains.
# 3. Visualise the data in different ways.

# %%
## Library

# Import pandas for reading in data and working with data tables and loading data
import pandas as pd

# Import the NumPy library for working with numbers and arrays
import numpy as np

# Import matplotlib for creating graphs and charts
import matplotlib.pyplot as plt

# This line makes sure that any plots you create will show up directly in the notebook
# %matplotlib inline

# %% [markdown]
# ## 1.1. Load Data
#
# ### Data and Models
# Good models start with good data. For the predator and prey relationship, data could be a record of how many animals are in each population at any given time. We will use predator-prey population data collected by a company that hunted both the predator and prey for their fur in the 19th and 20th centuries. The Hudson Bay Company made yearly records of the amount of Snow Lynx and Snowshoe Hare pelts they collected.
#
#
#
# ### Coding Exercise 1.1: Read the Data
# The data is contained in the __'DATA'__ folder in a csv file called __'hare_lynx_data.csv'__.
#
# Use the pandas (pd) library command __pd.read_csv__ to read the data and name it __Pred_prey_data__.
#
# This command reads in the data as a dataframe for easier examination and plotting of the data.

# %%
# Solution 1.1: Import CSV file containing predator-prey data (Hare and Lynx populations)
Pred_prey_data = pd.read_csv('DATA/hare_lynx_data.csv')

# %% [markdown]
# ## 1.2. Explore the data
# ### Coding Exercise 1.2.1: Read the first five rows
# Now the data is load it is good to check it.
# Have a look at the first five rwos of the data that using the __.head()__ command on the data.

# %%
# Solution 1.2.1: Show the first few rows
print("Here are the first 5 rows of the data:")
print(Pred_prey_data.head())
# Out:
# Here are the first 5 rows of the data:
#    Year   Hare   Lynx
# 0  1895  85.81  51.41
# 1  1896  56.69  46.43
# 2  1897  16.59  33.68
# 3  1898   6.16  18.01
# 4  1899   2.30   8.86

# %% [markdown]
# ### Coding Exercise 1.2.2: Types of data
# Have a look at what different types of data using the __.info()__ command.

# %%
# Solution 1.2.2: Show basic information about the data
print("\nInformation about the data:")
print(Pred_prey_data.info())
# Out:
# Information about the data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    41 non-null     int64
#  1   Hare    41 non-null     float64
#  2   Lynx    41 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.1 KB
# None

# %% [markdown]
# ###  Accessing specific data
# To find the population of Lynxes in the year 1900. You can use the command.

# %%
Pred_prey_data.Year==1900
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# Name: Year, dtype: bool

# %%
Pred_prey_data.Lynx[Pred_prey_data.Year==1900]
# Out:
# 5    7.13
# Name: Lynx, dtype: float64

# %%
Pred_prey_data.Lynx[5]
# Out:
# np.float64(7.13)

# %% [markdown]
# ###  Coding Exercise 1.2.3: Accessing specific data
# Give the Hare population for the year 1910.

# %%
# Solution 1.2.3: Accessing specific data

Pred_prey_data.Hare[Pred_prey_data.Year==1910]
# Out:
# 15    53.1
# Name: Hare, dtype: float64

# %% [markdown]
# ## 1.3. Plotting the data
#
# The best way to get a better feel for the data is to plot it.
#
# To do this use the __plt.plot(x,y,':o',label='y-name')__ command from the  matplotlib library.
#
#
# ### Coding Exercise 2.3.1: Plot the Hare data
# From the __Pred_prey_data__ dataframe plot the Hare data in green as the y-component and Year as the x-component.

# %%
# Create a new figure with a specified size (8 inches wide, 4 inches tall)
fig = plt.figure(figsize=(8, 4))

### Solution 2.3.1: Plot the Hare data
# Plot the Hare population over time using green dotted lines with circle markers
plt.plot(Pred_prey_data.Year, Pred_prey_data.Hare, 'o:', color='green')
### 

# Set the y-axis limits from 0 to 120 (tens of thousands)
plt.ylim(0, 120)

# Label the x-axis as 'Time (yrs)'
plt.xlabel('Time (yrs)')

# Label the y-axis as 'Hare Population (tens of thousands)'
plt.ylabel('Hare Population (tens of thousands)')

# Display the plot
plt.show()

# %% [markdown]
# ### Coding Exercise 1.3.2: Plot the Lynx data
# From the __Pred_prey_data__ dataframe plot the Lynx data in red as the y-component and Year as the x-component.

# %%
# Create a new figure with a specified size (8 inches wide, 4 inches tall)
fig = plt.figure(figsize=(8, 4))

### Solution 2.3.2: Plot the Lynx data
plt.plot(Pred_prey_data.Year,Pred_prey_data.Lynx,'o:',color='red')
####

# Set the y-axis limits from 0 to 120 (tens of thousands)
plt.ylim(0, 120)

# Label the x-axis as 'Time (yrs)'
plt.xlabel('Time (yrs)')

# Label the y-axis as 'Lynx Population (tens of thousands)'
plt.ylabel('Lynx Population (tens of thousands)')

# Display the plot
plt.show()

# %% [markdown]
# ### Coding Exercise 1.3.3: Plot the Hare and Lynx data
# Plot the Hare data in green and Lynx data in red using Year as function of Year on the same plot.

# %%
# Create a new figure with a specified size (8 inches wide, 4 inches tall)
fig = plt.figure(figsize=(8, 4))

### Solution 1.3.3: Plot the Hare and Lynx data as a function of time

# Plot Hare population over time using green dotted lines with circle markers
plt.plot(Pred_prey_data.Year, Pred_prey_data.Hare, 'o:', color='green', label='Hares')

# Plot Lynx population over time using red dotted lines with circle markers
plt.plot(Pred_prey_data.Year, Pred_prey_data.Lynx, 'o:', color='red', label='Lynxes')

### 

# Display a legend to differentiate between Hares and Lynxes
plt.legend()

# Set the y-axis limits from 0 to 120 (tens of thousands)
plt.ylim(0, 120)

# Label the x-axis as 'Time (yrs)'
plt.xlabel('Time (yrs)')

# Label the y-axis as 'Population (tens of thousands)'
plt.ylabel('Population (tens of thousands)')

# Show the plot
plt.show()

# %% [markdown]
# ### Reflective Exercise 1.4: Up and Down
#
# What patterns do you see in the data.
#
# * How does the lynx population pattern compare to the hare population trend over time?
#
# * Look for one period where the lynx population was increasing while the hare population was decreasing. What might this suggest about their relationship?
#
#
# ### Bonus Coding Exercise 1.5: Plot the data
# From the __Pred_prey_data__ dataframe plot the Lynx data as the x-component and the Hare data as the y-component.

# %%
# Create a new figure with a square size (6 inches by 6 inches)
fig = plt.figure(figsize=(6, 6))

### Solution 1.4: Plot the Hare as a function of Lynx data

# Plot Hare population against Lynx population using black dotted lines with circle markers
plt.plot(Pred_prey_data.Lynx, Pred_prey_data.Hare, 'k:o')
###

# Plot the mean point (average Lynx and Hare populations) as a black 'x' marker
plt.plot(np.mean(Pred_prey_data.Lynx), np.mean(Pred_prey_data.Hare), 'kx')

# Set the y-axis limits from 0 to 120 (tens of thousands)
plt.ylim(0, 120)

# Set the x-axis limits from 0 to 120 (tens of thousands)
plt.xlim(0, 120)

# Label the x-axis as 'Lynx Population (tens of thousands)'
plt.xlabel('Lynx Population (tens of thousands)')

# Label the y-axis as 'Hare Population (tens of thousands)'
plt.ylabel('Hare Population (tens of thousands)')

# Display the plot
plt.show()

# %% [markdown]
# ## Summary and Outro
# ### What does the Hudson Bay Data tell us?
#
# The rise and fall in the hare and lynx population over time suggests that there is a relationship between the two animals, which makes sense as we know that lynxes eat hares. The population of the lynxes and the hares fall and rise with a slight delay.
#
# When there are more lynxes, they eat more hares which decreases the hare population. When the hare population is low, this means less food for the lynxes and results in a decrease in the lynx population. When the lynx population decreases, the hare population will increase again, and the up-down cycle will continue. If the predator and prey populations are balanced, they will go up and down over time.
#
# Up and down like waves, the question a mathematician asks is, “can I explain this using addition, subtraction and multiplication and can I predict the future?”.
#
#
# __Next Lesson:__ Simulating the Hare population
